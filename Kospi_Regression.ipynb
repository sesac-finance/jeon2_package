# %% [markdown]
# # 다우존스 지수와 KOSPI의 회귀 분석

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
from scipy import stats
import matplotlib.pylab as plt

dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X':dow['Close'], 'Y':kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:.2f}  X + {regr.intercept:.2f}'

plt.figure(figsize=(10, 10))
plt.plot(df.X, df.Y, '.')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['DOW x KOSPI', regr_line])
plt.title(f'DOW x KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('DOW Jones Industrial Average')
plt.ylabel('KOSPI')
plt.show()

# %mkdir regression
plt.savefig('./regression/DowKospi_Regression.jpg')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# mkdir: `regression' 디렉토리를 만들 수 없습니다: 파일이 있습니다

# %%
df.corr()
# Out:
#           X         Y
# X  1.000000  0.825303
# Y  0.825303  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5886 entries, 2000-01-03 to 2022-09-13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       5886 non-null   float64
#  1   Y       5886 non-null   float64
# dtypes: float64(2)
# memory usage: 138.0 KB

# %%
df.head()
# Out:
#                        X            Y
# Date
# 2000-01-03  11357.509766  1059.040039
# 2000-01-04  10997.929688  1059.040039
# 2000-01-05  11122.650391   986.309998
# 2000-01-06  11253.259766   960.789978
# 2000-01-07  11522.559570   948.650024

# %%
df.tail()
# Out:
#                        X            Y
# Date
# 2022-09-07  31581.279297  2376.459961
# 2022-09-08  31774.519531  2384.280029
# 2022-09-09  32151.710938  2449.540039
# 2022-09-12  32381.339844  2449.540039
# 2022-09-13  32381.339844  2449.540039

# %% [markdown]
# # US Dollar Index(USDX)와 KOSPI의 회귀 분석

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
from scipy import stats
import matplotlib.pylab as plt

usdx = pdr.get_data_yahoo('DX-Y.NYB', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X':usdx['Close'], 'Y':kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:.2f}  X + {regr.intercept:.2f}'

plt.figure(figsize=(10, 10))
plt.plot(df.X, df.Y, '.')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['USDX x KOSPI', regr_line])
plt.title(f'USDX x KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('US Dollar Index')
plt.ylabel('KOSPI')
plt.show()

# %mkdir regression
plt.savefig('./regression/USDXKospi_Regression.jpg')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # US Dollar(USD)와 KOSPI의 회귀 분석

# %%
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
from scipy import stats
import matplotlib.pylab as plt

usd = pdr.get_data_yahoo('KRW=X', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X':usd['Close'], 'Y':kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:.2f}  X + {regr.intercept:.2f}'

plt.figure(figsize=(10, 10))
plt.plot(df.X, df.Y, '.')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['USDX x KOSPI', regr_line])
plt.title(f'USDX x KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('US Dollar Index')
plt.ylabel('KOSPI')
plt.show()

# %mkdir regression
plt.savefig('./regression/USDKospi_Regression.jpg')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
